# %%
from retinaface import RetinaFace
import cv2
import matplotlib.pyplot as plt

# %%
img_path ='1.jpg'
img = cv2.imread(img_path)

# %%
detector = RetinaFace.detect_faces(img_path)

# %%
detector
# Out:
# {'face_1': {'score': 0.999678373336792,
#   'facial_area': [126, 114, 194, 196],
#   'landmarks': {'right_eye': [141.40273, 145.49437],
#    'left_eye': [173.00803, 141.32117],
#    'nose': [158.06786, 159.51303],
#    'mouth_right': [149.44577, 177.75986],
#    'mouth_left': [173.03036, 174.19864]}},
#  'face_2': {'score': 0.9994766116142273,
#   'facial_area': [561, 339, 617, 409],
#   'landmarks': {'right_eye': [575.81274, 366.833],
#    'left_eye': [602.583, 365.67252],
#    'nose': [589.6417, 380.70532],
#    'mouth_right': [579.54364, 392.75464],
#    'mouth_left': [601.60156, 391.549]}},
#  'face_3': {'score': 0.9994658827781677,
#   'facial_area': [142, 351, 201, 424],
#   'landmarks': {'right_eye': [156.89444, 378.72314],
#    'left_eye': [186.6963, 377.121],
#    'nose': [172.68118, 391.42566],
#    'mouth_right': [162.90527, 408.24985],
#    'mouth_left': [185.33621, 406.67105]}},
#  'face_4': {'score': 0.9992983341217041,
#   'facial_area': [350, 347, 405, 418],
#   'landmarks': {'right_eye': [364.18533, 376.95517],
#    'left_eye': [390.04855, 377.6141],
#    'nose': [376.63583, 391.4434],
#    'mouth_right': [366.47473, 402.14008],
#    'mouth_left': [387.17166, 402.42734]}},
#  'face_5': {'score': 0.9990469813346863,
#   'facial_area': [358, 118, 408, 182],
#   'landmarks': {'right_eye': [374.79892, 145.35704],
#    'left_eye': [397.2338, 144.74355],
#    'nose': [387.6308, 157.99849],
#    'mouth_right': [378.31964, 169.42796],
#    'mouth_left': [394.51852, 168.67389]}},
#  'face_6': {'score': 0.9988736510276794,
#   'facial_area': [541, 78, 614, 171],
#   'landmarks': {'right_eye': [561.07526, 118.373405],
#    'left_eye': [597.4335, 116.88582],
#    'nose': [580.8402, 138.89792],
#    'mouth_right': [567.7482, 152.97292],
#    'mouth_left': [594.2796, 151.54066]}},
#  'face_7': {'score': 0.9985936284065247,
#   'facial_area': [366, 236, 399, 278],
#   'landmarks': {'right_eye': [374.56342, 252.34055],
#    'left_eye': [390.29828, 253.85974],
#    'nose': [380.52798, 260.33167],
#    'mouth_right': [374.4206, 268.37137],
#    'mouth_left': [386.68692, 269.59924]}},
#  'face_8': {'score': 0.998115062713623,
#   'facial_area': [152, 227, 192, 278],
#   'landmarks': {'right_eye': [162.90804, 245.96448],
#    'left_eye': [182.3536, 245.68315],
#    'nose': [172.998, 256.49588],
#    'mouth_right': [165.78056, 266.46655],
#    'mouth_left': [180.04959, 266.269]}},
#  'face_9': {'score': 0.9966598749160767,
#   'facial_area': [563, 224, 604, 279],
#   'landmarks': {'right_eye': [572.3083, 243.93279],
#    'left_eye': [592.1146, 244.4961],
#    'nose': [580.21655, 256.11392],
#    'mouth_right': [574.425, 266.64874],
#    'mouth_left': [588.64087, 267.10062]}}}

# %%
detector.keys()
# Out:
# dict_keys(['face_1', 'face_2', 'face_3', 'face_4', 'face_5', 'face_6', 'face_7', 'face_8', 'face_9'])

# %%
len(detector.keys())
# Out:
# 9

# %%
for key in detector.keys():
    identity = detector[key]
    #print(identity)
    facial_area = identity["facial_area"]
    cv2.rectangle(img,(facial_area[2],facial_area[3]),(facial_area[0],facial_area[1]), color = (0,0,255), thickness = 2)

# %%
plt.figure(figsize = (40,40))
plt.imshow(img[:,:,::-1])
plt.show()
